# %%
# https://www.pg4e.com/code/ipynb/00-magic.ipynb
    
# https://github.com/catherinedevlin/ipython-sql/blob/master/README.rst
# Adapted from: https://towardsdatascience.com/jupyter-magics-with-sql-921370099589
    
import pandas as pd

# %load_ext sql
# %config SqlMagic.autocommit=False

# %%
# Import hidden will fail when sending a notebook to the autograder
try:
    import hidden
    secrets = hidden.readonly()
    sql_string = hidden.alchemy(hidden.readonly())
    print('PostgreSQL connection data taken from hidden.py')
except:
    print('Manualy setting the postgreSQL connection')
    sql_string = 'postgresql://readonly:secret_xyzzy@pg.pg4e.com:5432/readonly'
# Out:
# PostgreSQL connection data taken from hidden.py

# %%
# Make the connection
# %sql $sql_string
# Out:
# 'Connected: readonly@readonly'

# %%
# A Basic query returning a result set that is displayed

# %sql SELECT * FROM taxdata LIMIT 100
# Out:
#  * postgresql://readonly:secret_xyzzy@pg.pg4e.com:5432/readonly
# 100 rows affected.
# [(1, 742661023, 'THE HARRIET & HARMON KELLEYFOUNDATION FOR THE ARTS', 2014, 0, 0, '', 'P00286016', 'JIM RICE', 'SAN ANTONIO', 'TX', 'https://s3.amazonaws.com/irs-form-990/201543159349100344_public.xml'),
#  (2, 562629114, 'BROWN COMMUNITY DEVELOPMENT CORPORATION', 2014, 116465, 115662, 'TO EDUCATE CHILDREN AND ORGANIZE COMMUNITY FOR BETTER LIVELIHOOD THE ORGANIZATION HELPS ELEMENTARY SCHOOL STUDENTS IN HOMEWORK HELP, STANDARDIZED TEST PREPARATION AND VARIOUS FIELD TRIPS.116465115662', '', 'SANJAY SINGLA CPA', 'BROOKLYN', 'NY', 'https://s3.amazonaws.com/irs-form-990/201543109349200219_public.xml'),
# ...

# %%
# A basic query converting a result set to a data frame

result = %sql SELECT * FROM taxdata LIMIT 100
result.DataFrame().head()
# Out:
#  * postgresql://readonly:secret_xyzzy@pg.pg4e.com:5432/readonly
# 100 rows affected.
#    id        ein                                               name  year  \
# 0   1  742661023  THE HARRIET & HARMON KELLEYFOUNDATION FOR THE ...  2014
# 1   2  562629114            BROWN COMMUNITY DEVELOPMENT CORPORATION  2014
# 2   3  270678774          KIWANIS CLUB OF GLENDORA PROJECTSFUND INC  2014
# 3   4  464114252                                CONFETTI FOUNDATION  2014
# 4   5  510311790                             THE SHEPHERD PLACE INC  2014
#
#    revenue  expenses                                            purpose  \
# 0        0         0
# 1   116465    115662  TO EDUCATE CHILDREN AND ORGANIZE COMMUNITY FOR...
# 2    39959     33918  TO SUPPORT AND SERVICE THE COMMUNITY OF GLENDO...
# 3    22881      7832  THE CONFETTI FOUNDATION SEEKS TO HONOR CHILDRE...
# 4   434413    464318  TO PROVIDE EMERGENCY SHELTER FOR HOMELESS FAMI...
#
# ...

# %%
# Bind Parameters

state='FINISHED'
# %sql SELECT :state as "bind_variable"
# Out:
#  * postgresql://readonly:secret_xyzzy@pg.pg4e.com:5432/readonly
# 1 rows affected.
# [('FINISHED',)]

# %%
# %%sql result << select * from
# taxdata
# limit 100;
# Out:
#  * postgresql://readonly:secret_xyzzy@pg.pg4e.com:5432/readonly
# 100 rows affected.
# Returning data to local variable result

# %%
result
# Out:
# [(1, 742661023, 'THE HARRIET & HARMON KELLEYFOUNDATION FOR THE ARTS', 2014, 0, 0, '', 'P00286016', 'JIM RICE', 'SAN ANTONIO', 'TX', 'https://s3.amazonaws.com/irs-form-990/201543159349100344_public.xml'),
#  (2, 562629114, 'BROWN COMMUNITY DEVELOPMENT CORPORATION', 2014, 116465, 115662, 'TO EDUCATE CHILDREN AND ORGANIZE COMMUNITY FOR BETTER LIVELIHOOD THE ORGANIZATION HELPS ELEMENTARY SCHOOL STUDENTS IN HOMEWORK HELP, STANDARDIZED TEST PREPARATION AND VARIOUS FIELD TRIPS.116465115662', '', 'SANJAY SINGLA CPA', 'BROOKLYN', 'NY', 'https://s3.amazonaws.com/irs-form-990/201543109349200219_public.xml'),
#  (3, 270678774, 'KIWANIS CLUB OF GLENDORA PROJECTSFUND INC', 2014, 39959, 33918, 'TO SUPPORT AND SERVICE THE COMMUNITY OF GLENDORA AND SURROUNDING COMMUNITIES. TO SUPPORT AND SERVICE THE COMMUNITY OF GLENDORA AND SURROUNDING COMMUNITIES.33825', 'P01414750', 'Robert E Davis', 'GLENDORA', 'CA', 'https://s3.amazonaws.com/irs-form-990/201513089349200226_public.xml'),
# ...

# %%
# Install https://pypi.org/project/pgspecial/

# %sql \dt
# Out:
#  * postgresql://readonly:secret_xyzzy@pg.pg4e.com:5432/readonly
# 7 rows affected.
# [('public', 'home_city', 'table', 'readwrite'),
#  ('public', 'home_county', 'table', 'readwrite'),
#  ('public', 'home_metro', 'table', 'readwrite'),
#  ('public', 'home_state', 'table', 'readwrite'),
#  ('public', 'home_value', 'table', 'readwrite'),
#  ('public', 'home_value_by_zip', 'table', 'readwrite'),
#  ('public', 'taxdata', 'table', 'readwrite')]
