# %% [markdown]
# SQL Magic Connection to the Read Only Database
# -----------------------------------------------------------
#
# In this assignment we make sure that you can properly make a connection to the read only database provided in class.  You should be given the database name, server, port, user name, and password separately in the course.  You can put them into the __hidden.py__ file but in order to pass the autograder you will also need to set the __sql_string__ variable since the auto grader won't have access to your __hidden.py__ file.

# %%
# https://github.com/catherinedevlin/ipython-sql/blob/master/README.rst
# Adapted from: https://towardsdatascience.com/jupyter-magics-with-sql-921370099589
    
import pandas as pd

# %load_ext sql
# %config SqlMagic.autocommit=False

# %%
# If you are going to send this file to the autograder, you cannot use hidden.py
# and must uncomment the magic_string assignment statement below and put in your values

magic_string = None
# magic_string = 'postgresql://pg4e_data_read:pg4e_pass_94e5d@35.239.113.162:10001/pg4e_data'
    
# If we leave magic_string as None, we can use hidden.py - but this only works for demo/test - not autograder
if magic_string is None:
    import hidden
    secrets = hidden.readonly()
    magic_string = hidden.alchemy(hidden.readonly())
    print('PostgreSQL connection data taken from hidden.py')
# Out:
# PostgreSQL connection data taken from hidden.py

# %%
# Make the connection
# %sql $magic_string
# Out:
# 'Connected: pg4e_data_read@pg4e_data'

# %%
# A Basic query returning a result set that is displayed

# %sql SELECT * FROM taxdata LIMIT 15
# Out:
#  * postgresql://pg4e_data_read:***@35.239.113.162:10014/pg4e_data
# 15 rows affected.
# [(1, 742661023, 'THE HARRIET & HARMON KELLEYFOUNDATION FOR THE ARTS', 2014, 0, 0, '', 'P00286016', 'JIM RICE', 'SAN ANTONIO', 'TX', 'https://s3.amazonaws.com/irs-form-990/201543159349100344_public.xml'),
#  (2, 562629114, 'BROWN COMMUNITY DEVELOPMENT CORPORATION', 2014, 116465, 115662, 'TO EDUCATE CHILDREN AND ORGANIZE COMMUNITY FOR BETTER LIVELIHOOD THE ORGANIZATION HELPS ELEMENTARY SCHOOL STUDENTS IN HOMEWORK HELP, STANDARDIZED TEST PREPARATION AND VARIOUS FIELD TRIPS.116465115662', '', 'SANJAY SINGLA CPA', 'BROOKLYN', 'NY', 'https://s3.amazonaws.com/irs-form-990/201543109349200219_public.xml'),
#  (3, 270678774, 'KIWANIS CLUB OF GLENDORA PROJECTSFUND INC', 2014, 39959, 33918, 'TO SUPPORT AND SERVICE THE COMMUNITY OF GLENDORA AND SURROUNDING COMMUNITIES. TO SUPPORT AND SERVICE THE COMMUNITY OF GLENDORA AND SURROUNDING COMMUNITIES.33825', 'P01414750', 'Robert E Davis', 'GLENDORA', 'CA', 'https://s3.amazonaws.com/irs-form-990/201513089349200226_public.xml'),
#  (4, 464114252, 'CONFETTI FOUNDATION', 2014, 22881, 7832, "THE CONFETTI FOUNDATION SEEKS TO HONOR CHILDREN WHO ARE SPENDING THEIR BIRTHDAY IN THE HOSPITAL BY PROVIDING A BIRTHDAY CELEBRATION. THE FOUNDATION S ... (250 characters truncated) ... HOPE FOR THE FUTURE AND AID IN THE HEALING PROCESS. PROVIDE BIRTHDAY CELEBRATIONS TO CHILDREN WHILE THEY ARE IN THE HOSPITAL ON THEIR BIRTHDAYS.07831", 'P00986503', 'MOLLY MCSHANE KELLY', 'NEWPORT', 'RI', 'https://s3.amazonaws.com/irs-form-990/201513089349200236_public.xml'),
#  (5, 510311790, 'THE SHEPHERD PLACE INC', 2014, 434413, 464318, 'TO PROVIDE EMERGENCY SHELTER FOR HOMELESS FAMILIES & INDIVIDUALS.', 'P00109363', 'RAYMOND F BOOK III', 'DOVER', 'DE', 'https://s3.amazonaws.com/irs-form-990/201523229349300327_public.xml'),
#  (6, 261460932, 'WISE VOLUNTEER FIRE DEPARTMENT INC', 2014, 522593, 27439, 'TO PROVIDE SUPPORT TO THE LOCAL FIRE DEPARTMENT FOR THE DEVELOPMENT AND MAINTANCE OF BUILDINGS AND EQUIMENT.', 'P00381273', 'LARRY D STURGILL', 'WISE', 'VA', 'https://s3.amazonaws.com/irs-form-990/201543089349301829_public.xml'),
#  (7, 270609504, 'A HOLE IN THE ROOF FOUNDATION', 2014, 422237, 384828, 'HELPS FAITH GROUPS WHO CARE FOR THE HOMELESS REPAIR THE SPACES IN WHICH THEY CARRY OUT THEIR WORK', 'P00086136', 'ROBERT W ELLERSHAW', 'DETROIT', 'MI', 'https://s3.amazonaws.com/irs-form-990/201533179349306298_public.xml'),
#  (8, 205710892, 'PTA CALIFORNIA CONGRESS OF PARENTSdba CARROLL ELEMENTARY PTA', 2014, 36594, 52857, 'THE PURPOSE OF THIS ASSOCIATION, IN CONNECTION WITH THE PURPOSES OF THE NATIONAL PTA AND THE CALIFORNIA STATE PTA ARE: A) TO PROMOTE THE WELFARE OF C ... (645 characters truncated) ... and supplies, supported school clubs, paid for license and testing fees, and sponsored and provided hospitality events for parents and students.48360', 'P00353546', 'Thomas A Mischley CPA', 'ELK GROVE', 'CA', 'https://s3.amazonaws.com/irs-form-990/201533179349201108_public.xml'),
#  (9, 251910030, 'LEAGUE OF THE SAN FRANCISCOCONSULAR CORPS', 2014, 3505, 19116, "TO SERVE AS A CENTER FOR ITS MEMBERS TO MEET AND TO OFFER SUPPORT AND ASSISTANCE TO INCOMING SAN FRANCISC0 BAY AREA CONSULAR CORP'S FAMILIES. TO PROM ... (44 characters truncated) ... OUGH EDUCATIONAL, SOCIAL AND CULTURAL EXCHANGES. TO ASSIST IN A PHILANTHROPIC WAY, NON PROFIT ORGANIZATIONS BASED IN THE SAN FRANCISCO BAY AREA.15831", 'P00175158', 'Chek Tan', 'SAN FRANCISCO', 'CA', 'https://s3.amazonaws.com/irs-form-990/201533179349203783_public.xml'),
#  (10, 521548962, 'TAXICAB LIMOUSINE & PARATRANSIT FOUNDATION', 2014, 287752, 50912, 'TRANSPORTATION RELATED EDUCATION', 'P00285909', "PATRICIA A O'MALLEY CPA", 'ROCKVILLE', 'MD', 'https://s3.amazonaws.com/irs-form-990/201533209349304768_public.xml'),
#  (11, 731653383, 'WHATCOM COUNTY NORTH ROTARY CLUB', 2014, 47319, 28123, 'CHARITABLE AND BENEVOLENT SERVICES PROMOTING THE OBJECT OF ROTARY INTERNATIONAL.', 'P00058649', 'JULIE JOHANSEN', 'FERNDALE', 'WA', 'https://s3.amazonaws.com/irs-form-990/201533179349307343_public.xml'),
#  (12, 10706544, 'NEW HORIZON ACADEMY FOR EXCEPTIONAL STUDENTSINC', 2013, 141515, 162890, 'THE SCHOOL IS FOR THE EDUCATION OF THE EXCEPTIAL STUDENT, BY PROVIDING A STRUCTURED LEARNING ENVIRONMENT, ORGANIZATION AND ADMINISTRERED BY PROFESSIO ... (134 characters truncated) ... with the structured organization and accountablity, and provide parents with educational materials and licensed educators and related services.159632', '', 'MARY C SCRIBNER CPA', 'Ocala', 'FL', 'https://s3.amazonaws.com/irs-form-990/201533209349204083_public.xml'),
#  (13, 274563334, 'Foundation for Corporate Tax Credit', 2014, 72211, 137300, 'TO PROVIDE SCHOLARSHIPS AND GRANTS FOR PRIVATE SCHOOL TUITION TO STUDENTS ATTENDING ONE OF THE FOUNDATION FOR CORPORATE TAX CREDIT MEMBER SCHOOLS SCHOLARSHIPS FOR STUDENTS IN ARIZONA NON PUBLIC SCHOOLS133800', 'P00262029', 'D Jack Roberts CPA', 'Tucson', 'AZ', 'https://s3.amazonaws.com/irs-form-990/201533209349204123_public.xml'),
#  (14, 262511957, 'MYTEAM TRIUMPH INC', 2014, 57813, 51143, 'PROVIDE RIDE ALONGS TO PEOPLE WITH DISABILITIES SUPPORT FOR CHAPTERS NATIONALLY THAT PROVIDE A RIDE-ALONG PROGRAM FOR CHILDREN, TEENS, ADULTS, AND VETERANS WITH DISABILITIES WHO WOULD NOT NORMALLY BE ABLE TO EXPERIENCE ENDURANCE EVENTS SUCH AS TRIATHALONS OR ROAD RACES051143', '', '', 'ADA', 'MI', 'https://s3.amazonaws.com/irs-form-990/201533209349204128_public.xml'),
#  (15, 272260017, 'Sulgrave Manor Preservation Foundation', 2014, 24409, 42650, 'See Schedule O N/A', '', 'TODD H DITTRICH', 'Cincinnati', 'OH', 'https://s3.amazonaws.com/irs-form-990/201533209349204148_public.xml')]

# %%
# Out:
#  * postgresql://pg4e_data_read:***@35.239.113.162:10014/pg4e_data
# 1 rows affected.
#  * postgresql://pg4e_data_read:***@35.239.113.162:10014/pg4e_data
# 1 rows affected.
